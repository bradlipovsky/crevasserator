# %%
import pickle
import matplotlib.pyplot as plt

with open('modal.pickle', 'rb') as f:
    K = pickle.load(f)

plt.plot(K[:,0],-K[:,1],'-o')
plt.plot(K[:,0],-K[:,2],'-o')
plt.xscale('log')
plt.grid()

# %%
K
# Out:
# array([[ 1.00000000e+01,  9.70593564e+02,  5.76895163e+02],
#        [ 2.32691817e+01,  8.11613648e+02, -9.09146438e+02],
#        [ 5.41454816e+01, -5.89205747e+03, -2.24418525e+03],
#        [ 1.25992105e+02, -1.44776766e+04, -1.29065783e+03],
#        [ 2.93173318e+02, -1.01413794e+04, -1.79115350e+02],
#        [ 6.82190321e+02, -3.27787454e+03,  1.57721842e+02],
#        [ 1.58740105e+03, -2.61065016e+03, -6.58364128e+00],
#        [ 3.69375235e+03, -2.34652342e+03, -4.61210346e+00],
#        [ 8.59505945e+03, -6.92639429e+02, -8.80043209e+00],
#        [ 2.00000000e+04,  2.59905981e+03,  6.83969726e-01]])
